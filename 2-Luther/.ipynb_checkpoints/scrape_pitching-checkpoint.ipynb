# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import html5lib
import requests
import numpy as np
import os

# %%
#Use BeautifulSoup and Selenium to scrape data from baseball-reference.com

url='https://www.baseball-reference.com/leagues/MLB/2017-value-pitching.shtml'

import os
chromedriver = "/Users/ryanmurray/Downloads/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver


driver = webdriver.Chrome(chromedriver)

driver.get(url)
soup = BeautifulSoup(driver.page_source,'lxml')
driver.quit()

# %%
def scrape(url):
    chromedriver = "/Users/ryanmurray/Downloads/chromedriver" # path to the chromedriver executable
    os.environ["webdriver.chrome.driver"] = chromedriver


    driver = webdriver.Chrome(chromedriver)

    driver.get(url)
    soup = BeautifulSoup(driver.page_source,'lxml')
    driver.quit()
    
    return soup

# %%
def parse_table(soup,table="table_name"):
    
    #takes table with "table_name" from scraped website and outputs pandas dataframe
    tab = soup.find("table",{"id": table})
    rows = tab.find_all('tr')
    
    #get header and remove leading and trailing blank strings
    header = rows[0].text.split('\n')
    header.remove('')
    header.remove('')
    
    #create list of rows
    rows_list = []
    for row in rows:
        cur_row = []
        for c in row:
            try: cur_row.append(c.text)
            except: cur_row.append('')
        if len(cur_row) == len(header):
            rows_list.append(cur_row)
            
    return pd.DataFrame(rows_list,columns=header)

# %%
def scrape_and_parse(url,table):
    soup = scrape(url)
    df = parse_table(soup, table)
    return df

# %%
#parse data into 

p_table = soup.find("table", {"id": "players_value_pitching"})
p_rows = p_table.find_all('tr')

p_header = p_rows[0].text.split('\n')
p_header.remove('')
p_header.remove('')

p_rows_list = []
for row in p_rows[1:]:
    cur_row = []
    for c in row:
        try:
            cur_row.append(c.text)
        except:
            cur_row.append('')
    if len(cur_row) == len(:
        p_rows_list.append(cur_row)

# %%
p_df = pd.DataFrame(p_rows_list, columns=p_header)

# %%
p_col = p_df.columns.tolist()

# %%
for col in p_col:
    try:
        p_df[col] = pd.to_numeric(p_df[col])
    except:
        pass

# %%
p_df['sal'] = pd.to_numeric(p_df['Salary'].apply(lambda x: (x.replace('$','').replace(',',''))))

# %%
p_short = p_df.dropna()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(p_short['WAR'],p_short['sal'])

# %%
plt.hist(p_short['WAR'])
# Out:
# (array([  3.,  10.,  38., 100.,  73.,  42.,  28.,  14.,  12.,   5.]),
#  array([-2.2 , -1.61, -1.02, -0.43,  0.16,  0.75,  1.34,  1.93,  2.52,
#          3.11,  3.7 ]),
#  <a list of 10 Patch objects>)

# %%
p_short['log_sal'] = p_short['sal'].apply(lambda x: np.log10(x))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.scatter(p_short['WAR'],p_short['log_sal'])

# %%
p_abv_min = p_short[p_short['log_sal']>5.75]

# %%
plt.scatter(p_abv_min['WAR'],p_abv_min['log_sal'])

# %%
corr = p_abv_min.corr()

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(corr)

# %%
plt.hist(p_abv_min['log_sal'])
# Out:
# (array([15., 25., 30., 18., 28., 37., 24., 11.,  7.,  2.]),
#  array([5.75089392, 5.92351665, 6.09613939, 6.26876212, 6.44138485,
#         6.61400759, 6.78663032, 6.95925305, 7.13187579, 7.30449852,
#         7.47712125]),
#  <a list of 10 Patch objects>)

# %%
p_tw = p_abv_min[p_abv_min['G']>20]

# %%
p_short.shape
# Out:
# (325, 26)

# %%
p_df.shape
# Out:
# (755, 25)

# %%
plt.scatter(p_tw['RA9role'],p_tw['log_sal'])

# %%
s = 'Fernando Abad*'
p = "Hello"

# %%
'*' in p
# Out:
# False

# %%
def is_lhp(p):
    return '*' in p


def drop_ast(n):
    return n.replace('*','')

# %%
p_df['lhp'] = p_df['Name'].apply(is_lhp)

p_df['Name'] = p_df['Name'].apply(drop_ast)

# %%
p_df
# Out:
#       Rk                 Name  Age   Tm     IP   G  GS    R    RA9  RA9opp  \
# 0      1        Fernando Abad   31  BOS   43.2  48   0   18   3.71    4.78
# 1      2         Austin Adams   26  WSN    5.0   6   0    4   7.20    4.88
# 2      3          Tim Adleman   29  CIN  122.1  30  20   79   5.81    4.70
# 3      4        Andrew Albers   31  SEA   41.0   9   6   22   4.83    4.78
# 4      5          Matt Albers   34  WSN   61.0  63   0   12   1.77    4.70
# 5      6      Al Alburquerque   31  2TM   18.0  21   0    5   2.50    4.80
# 6      7       Raul Alcantara   24  OAK   24.0   8   4   21   7.88    4.86
# 7      8      Sandy Alcantara   21  STL    8.1   8   0    6   6.48    4.64
# 8      9     Victor Alcantara   24  DET    7.1   6   0    7   8.59    4.91
# 9     10      Scott Alexander   27  KCR   69.0  58   0   23   3.00    4.80
# 10    11           Cody Allen   28  CLE   67.1  69   0   24   3.21    4.77
# 11    12       Miguel Almonte   24  KCR    2.0   2   0    3  13.50    5.13
# 12    13        Dan Altavilla   24  SEA   46.2  41   0   27   5.21    5.06
# 13    14        Jose Alvarado   22  TBR   29.2  35   0   12   3.64    4.89
# 14    15        Dario Alvarez   28  TEX   16.1  20   0    8   4.41    4.96
# 15    16    Henderson Alvarez   27  PHI   14.2   3   3    7   4.30    4.68
# 16    17         Jose Alvarez   28  LAA   48.2  64   0   23   4.25    4.96
# 17    18       Brett Anderson   29  2TM   55.1  13  13   41   6.67    4.71
# 18    19       Chase Anderson   29  MIL  141.1  25  25   47   2.99    4.58
# 19    20        Drew Anderson   23  PHI    2.1   2   0    7  27.00    4.86
# 20    21       Tyler Anderson   27  COL   86.0  17  15   48   5.02    4.68
# 21    22        Matt Andriese   27  TBR   86.0  18  17   48   5.02    4.76
# 22    23       Norichika Aoki   35  HOU    1.0   1   0    3  27.00    5.17
# 23    24        Jayson Aquino   24  BAL   13.1   4   2   12   8.10    4.67
# 24    25         Victor Arano   22  PHI   10.2  10   0    2   1.69    5.04
# 25    26         Chris Archer   28  TBR  201.0  34  34  101   4.52    4.72
# 26    27      Shawn Armstrong   26  CLE   24.2  21   0   12   4.38    4.63
# 27    28         Jake Arrieta   31  CHC  168.1  30  30   82   4.38    4.60
# 28    29       Bronson Arroyo   40  CIN   71.0  14  14   59   7.48    4.60
# 29    30           Alec Asher   25  BAL   60.0  24   6   36   5.40    4.60
# ..   ...                  ...  ...  ...    ...  ..  ..  ...    ...     ...
# 725  726      Aaron Wilkerson   28  MIL   10.1   3   2    4   3.48    4.68
# 726  727      Taylor Williams   25  MIL    4.2   5   0    1   1.93    4.88
# 727  728      Trevor Williams   25  PIT  150.1  31  25   73   4.37    4.66
# 728  729          Alex Wilson   30  DET   60.0  66   0   34   5.10    4.79
# 729  730        Justin Wilson   29  2TM   58.0  65   0   23   3.57    4.76
# 730  731         Tyler Wilson   27  BAL   15.1   9   1   14   8.22    4.75
# 731  732         Alex Wimmers   28  MIN    7.1   6   0    4   4.91    4.75
# 732  733          Dan Winkler   27  ATL   14.1  16   0    4   2.51    4.81
# 733  734          Matt Wisler   24  ATL   32.1  20   1   31   8.63    4.73
# 734  735        Nick Wittgren   26  MIA   42.1  38   0   22   4.68    4.81
# 735  736  Asher Wojciechowski   28  CIN   62.1  25   8   48   6.93    4.75
# 736  737            Alex Wood   26  LAD  152.1  27  25   50   2.95    4.56
# 737  738           Blake Wood   31  2TM   74.1  72   0   49   5.93    4.80
# 738  739          Hunter Wood   23  TBR    0.1   1   0    0   0.00    4.62
# 739  740          Travis Wood   30  2TM   94.0  39  14   77   7.37    4.77
# 740  741     Brandon Woodruff   24  MIL   43.0   8   8   23   4.81    4.84
# 741  742      Brandon Workman   28  BOS   39.2  33   0   17   3.86    4.79
# 742  743         Vance Worley   29  MIA   71.2  24  12   56   7.03    4.76
# 743  744        Daniel Wright   26  LAA   19.2   5   2   12   5.49    4.45
# 744  745          Mike Wright   27  BAL   25.0  13   0   16   5.76    4.72
# 745  746        Steven Wright   32  BOS   24.0   5   5   24   9.00    4.82
# 746  747      Jimmy Yacabonis   25  BAL   20.2  14   0   10   4.35    4.65
# 747  748          Kirby Yates   30  2TM   56.2  62   0   28   4.45    4.71
# 748  749         Gabriel Ynoa   24  BAL   34.2   9   4   17   4.41    4.83
# 749  750         Michael Ynoa   25  CHW   29.0  22   0   22   6.83    4.86
# 750  751          Chris Young   38  KCR   30.0  14   2   27   8.10    4.85
# 751  752        Rob Zastryzny   25  CHC   13.0   4   0   13   9.00    4.66
# 752  753         Brad Ziegler   37  MIA   47.0  53   0   29   5.55    4.70
# 753  754    Jordan Zimmermann   31  DET  160.0  29  29  111   6.24    4.88
# 754  755            Tony Zych   26  SEA   40.2  45   0   12   2.66    4.74
#
#      ...    gmLI  WAAadj  WAR   RAR  waaWL%  162WL%       Salary  \
# 0    ...    0.68    -0.2  0.5   7.0   0.505   0.501   $2,000,000
# 1    ...    0.06     0.1  0.0  -1.0   0.477   0.499
# 2    ...    1.04    -0.1 -0.5  -4.0   0.452   0.491
# 3    ...    0.99     0.0  0.3   4.0   0.490   0.499
# 4    ...    1.10    -0.1  2.4  24.0   0.531   0.512   $1,150,000
# 5    ...    0.63    -0.1  0.5   6.0   0.520   0.501
# 6    ...    0.12     0.1 -0.3  -4.0   0.418   0.496     $535,000
# 7    ...    0.16     0.1 -0.1  -1.0   0.472   0.499
# 8    ...    0.19     0.1 -0.1  -2.0   0.456   0.498
# 9    ...    1.60     0.2  2.2  21.0   0.523   0.508
# 10   ...    1.63     0.1  1.7  17.0   0.513   0.506   $7,350,000
# 11   ...    0.32     0.1 -0.1  -2.0   0.416   0.499
# 12   ...    0.73    -0.1  0.0   1.0   0.490   0.497     $536,100
# 13   ...    1.21    -0.1  0.3   4.0   0.503   0.501
# 14   ...    1.23     0.0  0.2   3.0   0.504   0.500     $538,790
# 15   ...     NaN     0.0  0.2   2.0   0.538   0.501
# 16   ...    1.18    -0.2  0.2   4.0   0.498   0.499     $557,500
# 17   ...     NaN     0.0 -0.4  -5.0   0.432   0.497   $3,500,000
# 18   ...     NaN    -0.1  4.2  41.0   0.622   0.519   $2,450,000
# 19   ...    0.16     0.2 -0.3  -6.0   0.272   0.497
# 20   ...    0.84    -0.1  1.2  13.0   0.531   0.503     $540,000
# 21   ...    0.09    -0.1  0.1   3.0   0.463   0.496     $547,500
# 22   ...    0.01     0.1 -0.1  -2.0   0.292   0.499   $5,500,000
# 23   ...    1.16     0.0 -0.3  -3.0   0.393   0.497
# 24   ...    0.97     0.0  0.4   4.0   0.536   0.502
# 25   ...     NaN    -0.1  1.3  17.0   0.484   0.497   $4,916,666
# 26   ...    0.16    -0.1  0.2   3.0   0.500   0.500     $535,700
# 27   ...     NaN    -0.1  1.9  21.0   0.517   0.503  $15,637,500
# 28   ...     NaN     0.0 -1.4 -16.0   0.356   0.488     $535,000
# 29   ...    0.78    -0.1  0.0   2.0   0.479   0.497
# ..   ...     ...     ...  ...   ...     ...     ...          ...
# 725  ...   -0.02     0.0  0.2   2.0   0.544   0.501
# 726  ...    0.03    -0.1  0.1   2.0   0.527   0.501
# 727  ...    0.70    -0.1  2.0  21.0   0.525   0.505     $544,000
# 728  ...    1.17    -0.2  0.4   6.0   0.499   0.500   $1,175,000
# 729  ...    1.44     0.2  1.5  13.0   0.511   0.503   $2,700,000
# 730  ...    0.80     0.0 -0.4  -4.0   0.438   0.497     $545,000
# 731  ...    0.34     0.0  0.0   0.0   0.488   0.500
# 732  ...    1.36     0.0  0.5   4.0   0.519   0.502     $545,000
# 733  ...    0.29     0.3 -0.8 -11.0   0.431   0.491
# 734  ...    0.81    -0.1  0.0   1.0   0.492   0.498     $535,000
# 735  ...    0.63     0.0 -0.9 -10.0   0.438   0.490
# 736  ...    1.27    -0.1  3.4  34.0   0.580   0.513   $2,800,000
# 737  ...    0.73     0.0 -0.6  -6.0   0.481   0.494   $1,275,000
# 738  ...    0.11     0.0  0.0   0.0   0.517   0.500
# 739  ...    0.92    -0.1 -1.8 -18.0   0.435   0.493   $4,000,000
# 740  ...     NaN     0.0  0.5   5.0   0.517   0.501
# 741  ...    0.94    -0.1  0.4   6.0   0.505   0.501     $635,000
# 742  ...    0.50     0.0 -1.3 -14.0   0.417   0.488
# 743  ...    0.20     0.0 -0.1  -2.0   0.427   0.498
# 744  ...    0.34     0.0 -0.1  -1.0   0.472   0.498
# 745  ...     NaN     0.0 -0.7  -9.0   0.308   0.494     $593,500
# 746  ...    0.51    -0.1  0.2   2.0   0.500   0.500
# 747  ...    1.05    -0.1  0.3   4.0   0.498   0.500
# 748  ...    0.54    -0.1  0.5   6.0   0.523   0.501
# 749  ...    0.31     0.2 -0.3  -4.0   0.466   0.495     $540,000
# 750  ...    0.34     0.2 -0.6  -8.0   0.425   0.494   $5,750,000
# 751  ...    0.36     0.2 -0.3  -6.0   0.346   0.496
# 752  ...    1.42    -0.3 -0.7  -4.0   0.484   0.495   $7,000,000
# 753  ...     NaN    -0.1  0.3   6.0   0.461   0.493  $18,000,000
# 754  ...    1.34     0.0  1.1  11.0   0.515   0.504     $539,600
#
#                Acquired         sal    lhp
# 0                Traded   2000000.0   True
# 1                Traded         NaN  False
# 2           Free Agency         NaN  False
# 3             Purchased         NaN   True
# 4           Free Agency   1150000.0  False
# 5           Free Agency         NaN  False
# 6                Traded    535000.0  False
# 7    Amateur Free Agent         NaN  False
# 8                Traded         NaN  False
# 9         Amateur Draft         NaN   True
# 10        Amateur Draft   7350000.0  False
# 11   Amateur Free Agent         NaN  False
# 12        Amateur Draft    536100.0  False
# 13   Amateur Free Agent         NaN   True
# 14               Traded    538790.0   True
# 15          Free Agency         NaN  False
# 16               Traded    557500.0   True
# 17          Free Agency   3500000.0   True
# 18               Traded   2450000.0  False
# 19        Amateur Draft         NaN  False
# 20        Amateur Draft    540000.0   True
# 21               Traded    547500.0  False
# 22              Waivers   5500000.0  False
# 23          Free Agency         NaN   True
# 24               Traded         NaN  False
# 25               Traded   4916666.0  False
# 26        Amateur Draft    535700.0  False
# 27               Traded  15637500.0  False
# 28          Free Agency    535000.0  False
# 29               Traded         NaN  False
# ..                  ...         ...    ...
# 725              Traded         NaN  False
# 726       Amateur Draft         NaN  False
# 727              Traded    544000.0  False
# 728              Traded   1175000.0  False
# 729              Traded   2700000.0   True
# 730       Amateur Draft    545000.0  False
# 731         Free Agency         NaN  False
# 732        Rule 5 Draft    545000.0  False
# 733              Traded         NaN  False
# 734       Amateur Draft    535000.0  False
# 735         Free Agency         NaN  False
# 736              Traded   2800000.0   True
# 737         Free Agency   1275000.0  False
# 738       Amateur Draft         NaN  False
# 739         Free Agency   4000000.0   True
# 740       Amateur Draft         NaN  False
# 741       Amateur Draft    635000.0  False
# 742         Free Agency         NaN  False
# 743             Waivers         NaN  False
# 744       Amateur Draft         NaN  False
# 745              Traded    593500.0  False
# 746       Amateur Draft         NaN  False
# 747             Waivers         NaN  False
# 748           Purchased         NaN  False
# 749              Traded    540000.0  False
# 750         Free Agency   5750000.0  False
# 751       Amateur Draft         NaN   True
# 752         Free Agency   7000000.0  False
# 753         Free Agency  18000000.0  False
# 754           Purchased    539600.0  False
#
# [755 rows x 26 columns]

# %%
url_2016 = 'https://www.baseball-reference.com/leagues/MLB/2016-value-pitching.shtml'
table_name = 'players_value_pitching'

p_2016 = scrape_and_parse(url_2016,table_name)

# %%
p_2016
# Out:
#       Rk               Name Age   Tm     IP   G  GS    R    RA9 RA9opp  \
# 0      1     Fernando Abad*  30  2TM   46.2  57   0   20   3.86   4.66
# 1      2        A.J. Achter  27  LAA   37.2  27   0   13   3.11   4.57
# 2      3       Austin Adams  29  CLE   18.1  19   0   22  10.80   4.57
# 3      4        Tim Adleman  28  CIN   69.2  13  13   32   4.13   4.55
# 4      5     Andrew Albers*  30  MIN   17.0   6   2   16   8.47   4.61
# 5      6        Matt Albers  33  CHW   51.1  58   1   44   7.71   4.59
# 6      7    Al Alburquerque  30  LAA    2.0   2   0    3  13.50   4.49
# 7      8     Raul Alcantara  23  OAK   22.1   5   5   18   7.25   4.72
# 8      9   Scott Alexander*  26  KCR   19.0  17   0    7   3.32   4.48
# 9     10         Cody Allen  27  CLE   68.0  67   0   23   3.04   4.53
# 10    11      Dan Altavilla  23  SEA   12.1  15   0    1   0.73   4.69
# 11    12     Dario Alvarez*  27  2TM   26.2  26   0   16   5.40   4.56
# 12    13      Jose Alvarez*  27  LAA   57.1  64   0   29   4.55   4.71
# 13    14     Alexi Amarista  27  SDP    0.1   1   0    0   0.00   4.89
# 14    15    Brett Anderson*  28  LAD   11.1   4   3   15  11.91   4.53
# 15    16     Chase Anderson  28  MIL  151.2  31  30   83   4.93   4.52
# 16    17      Cody Anderson  25  CLE   60.2  19   9   45   6.68   4.57
# 17    18    Tyler Anderson*  26  COL  114.1  19  19   50   3.94   4.44
# 18    19      Matt Andriese  26  TBR  127.2  29  19   64   4.51   4.61
# 19    20     Dustin Antolin  26  TOR    2.0   1   0    3  13.50   4.36
# 20    21     Jayson Aquino*  23  BAL    2.1   3   0    0   0.00   5.12
# 21    22      Elvis Araujo*  24  PHI   27.1  32   0   22   7.24   4.50
# 22    23       Chris Archer  27  TBR  201.1  33  33  100   4.47   4.63
# 23    24    Shawn Armstrong  25  CLE   10.2  10   0    3   2.53   4.60
# 24    25       Jonathan Aro  25  SEA    0.2   1   0    0   0.00   4.74
# 25    26       Jake Arrieta  30  CHC  197.1  31  31   72   3.28   4.51
# 26    27         Alec Asher  24  PHI   27.2   5   5   11   3.58   4.44
# 27    28       Luis Avilan*  26  LAD   19.2  27   0    8   3.66   4.77
# 28    29        John Axford  33  OAK   65.2  68   0   30   4.11   4.67
# 29    30         Pedro Baez  28  LAD   74.0  73   0   27   3.28   4.53
# ..   ...                ...  ..  ...    ...  ..  ..  ...    ...    ...
# 712  713        Tyler White  25  HOU    1.0   1   0    1   9.00   4.51
# 713  714      Chase Whitley  27  TBR   14.1   5   1    7   4.40   4.43
# 714  715        Joe Wieland  26  SEA    5.0   1   1    6  10.80   4.22
# 715  716     Tom Wilhelmsen  32  2TM   46.1  50   0   35   6.80   4.69
# 716  717    Jerome Williams  34  STL   17.1  11   0   15   7.79   4.42
# 717  718    Trevor Williams  24  PIT   12.2   7   1   13   9.24   4.51
# 718  719        Alex Wilson  29  DET   73.0  62   0   26   3.21   4.55
# 719  720     Justin Wilson*  28  DET   58.2  66   0   29   4.45   4.60
# 720  721       Tyler Wilson  26  BAL   94.0  24  13   57   5.46   4.70
# 721  722       Alex Wimmers  27  MIN   17.1  16   0    8   4.15   4.54
# 722  723        Dan Winkler  26  ATL    2.1   3   0    0   0.00   4.71
# 723  724        Matt Wisler  23  ATL  156.2  27  26   90   5.17   4.41
# 724  725      Chris Withrow  27  ATL   37.2  46   0   16   3.82   4.53
# 725  726      Nick Wittgren  25  MIA   51.2  48   0   18   3.14   4.45
# 726  727         Alex Wood*  25  LAD   60.1  14  10   30   4.48   4.54
# 727  728         Blake Wood  30  CIN   76.2  70   0   38   4.46   4.53
# 728  729       Travis Wood*  29  CHC   61.0  77   0   24   3.54   4.60
# 729  730       Vance Worley  28  BAL   86.2  35   4   37   3.84   4.62
# 730  731      Daniel Wright  25  2TM   39.2   9   7   32   7.26   4.59
# 731  732        Mike Wright  26  BAL   74.2  18  12   53   6.39   4.55
# 732  733      Steven Wright  31  BOS  156.2  24  24   74   4.25   4.50
# 733  734        Kirby Yates  29  NYY   41.1  41   0   24   5.23   4.52
# 734  735       Gabriel Ynoa  23  NYM   18.1  10   3   13   6.38   4.24
# 735  736       Michael Ynoa  24  CHW   30.0  23   0   11   3.30   4.46
# 736  737        Chris Young  37  KCR   88.2  34  13   63   6.39   4.59
# 737  738  Madison Younginer  25  ATL    7.0   8   0    5   6.43   4.36
# 738  739     Rob Zastryzny*  24  CHC   16.0   8   1    3   1.69   4.61
# 739  740       Brad Ziegler  36  2TM   68.0  69   0   21   2.78   4.46
# 740  741  Jordan Zimmermann  30  DET  105.1  19  18   63   5.38   4.40
# 741  742          Tony Zych  25  SEA   13.2  12   0    6   3.95   4.45
#
#             ...          RAA   WAA  gmLI WAAadj   WAR  RAR waaWL% 162WL%  \
# 0           ...            3   0.3  1.37   -0.1   0.8    8   .506   .502
# 1           ...            2   0.3   .43   -0.2   0.5    6   .509   .502
# 2           ...          -13  -1.3   .36    0.4  -0.7  -11   .433   .492
# 3           ...            6   0.7         -0.1   1.3   12   .553   .504
# 4           ...           -7  -0.6   .22    0.1  -0.3   -5   .396   .496
# 5           ...          -20  -2.0  1.32   -0.4  -1.9  -14   .465   .488
# 6           ...           -2  -0.2   .18    0.1  -0.1   -2   .395   .499
# 7           ...           -5  -0.5          0.0  -0.3   -2   .408   .497
# 8           ...            2   0.2   .64   -0.1   0.3    4   .510   .501
# 9           ...           10   1.0  1.56    0.1   1.8   17   .515   .506
# 10          ...            5   0.5   .63   -0.1   0.5    6   .532   .503
# 11          ...           -3  -0.3   .99    0.2   0.2    0   .490   .500
# 12          ...           -4  -0.4  1.04   -0.1   0.0    2   .494   .497
# 13          ...            0   0.0   .00    0.0   0.0    0   .517   .500
# 14          ...          -10  -0.8   .82    0.0  -0.7   -9   .294   .495
# 15          ...           -2  -0.3   .74   -0.1   1.0   10   .492   .498
# 16          ...          -14  -1.4   .72    0.0  -0.8   -7   .428   .492
# 17          ...           21   2.3         -0.1   3.2   30   .621   .514
# 18          ...           -1  -0.1  1.20   -0.1   1.1   13   .497   .499
# 19          ...           -2  -0.2   .33    0.1  -0.1   -2   .313   .499
# 20          ...            1   0.1   .13   -0.1   0.1    2   .546   .501
# 21          ...           -9  -0.9   .89    0.0  -0.7   -6   .472   .495
# 22          ...            1   0.1         -0.1   2.0   23   .504   .501
# 23          ...            2   0.2   .68   -0.1   0.3    3   .524   .501
# 24          ...            0   0.0  1.57    0.0   0.1    0   .536   .500
# 25          ...           19   2.1         -0.1   3.7   36   .568   .513
# 26          ...            4   0.4          0.0   0.7    6   .586   .503
# 27          ...            2   0.2  1.19    0.0   0.3    3   .506   .501
# 28          ...            3   0.3  1.22   -0.1   0.9   10   .505   .502
# 29          ...            6   0.6  1.18   -0.1   1.2   12   .508   .504
# ..          ...          ...   ...   ...    ...   ...  ...    ...    ...
# 712         ...           -1  -0.1   .00    0.0   0.0    0   .443   .500
# 713         ...            0   0.0  1.14    0.0   0.1    1   .493   .500
# 714         ...           -4  -0.3          0.0  -0.2   -3   .225   .498
# 715         ...          -13  -1.3  1.17   -0.1  -0.9   -8   .475   .497
# 716         ...           -7  -0.7   .04    0.3  -0.3   -6   .436   .496
# 717         ...           -7  -0.6   .93    0.0  -0.5   -6   .410   .496
# 718         ...           11   1.2  1.26    0.0   1.9   19   .519   .507
# 719         ...            1   0.1  1.37   -0.1   0.5    7   .501   .500
# 720         ...           -5  -0.5   .54   -0.1   0.4    5   .479   .497
# 721         ...            1   0.1  1.12    0.0   0.2    3   .505   .500
# 722         ...            1   0.1  2.19    0.1   0.2    1   .541   .501
# 723         ...           -7  -0.7  3.36   -0.1   0.5    6   .473   .496
# 724         ...            2   0.2  1.21   -0.1   0.5    5   .505   .501
# 725         ...            4   0.4   .99   -0.1   0.8    8   .509   .503
# 726         ...           -1  -0.1   .26   -0.1   0.4    4   .496   .500
# 727         ...            0   0.0  1.21   -0.2   0.5    6   .500   .500
# 728         ...            1   0.1  1.13   -0.1   0.6    6   .502   .501
# 729         ...            8   0.8   .64   -0.3   1.4   17   .523   .505
# 730         ...          -12  -1.1  1.20   -0.1  -0.8   -8   .381   .497
# 731         ...          -12  -1.2   .27    0.0  -0.5   -4   .434   .493
# 732         ...            5   0.5         -0.1   2.0   22   .522   .503
# 733         ...           -4  -0.5   .71    0.0  -0.1    0   .489   .497
# 734         ...           -4  -0.4   .57    0.0  -0.3   -3   .456   .497
# 735         ...            3   0.3   .42   -0.2   0.4    6   .513   .502
# 736         ...          -20  -2.0   .55    0.0  -1.0  -10   .443   .488
# 737         ...           -2  -0.2   .67    0.0  -0.1   -1   .480   .499
# 738         ...            4   0.5  1.13    0.0   0.6    6   .560   .503
# 739         ...           12   1.2  1.77    0.3   2.2   18   .518   .504
# 740         ...           -6  -0.6   .11   -0.1   0.4    6   .470   .496
# 741         ...            0   0.0   .52    0.0   0.1    2   .501   .500
#
#           Salary            Acquired
# 0     $1,250,000              Traded
# 1                            Waivers
# 2                      Amateur Draft
# 3                        Free Agency
# 4                        Free Agency
# 5     $2,000,000         Free Agency
# 6     $1,100,000         Free Agency
# 7                             Traded
# 8                      Amateur Draft
# 9     $4,150,000       Amateur Draft
# 10                     Amateur Draft
# 11                           Waivers
# 12      $519,500              Traded
# 13    $1,350,000              Traded
# 14   $15,800,000         Free Agency
# 15      $520,200              Traded
# 16      $511,400       Amateur Draft
# 17                     Amateur Draft
# 18                            Traded
# 19                       Free Agency
# 20                         Purchased
# 21                       Free Agency
# 22    $2,916,666              Traded
# 23                     Amateur Draft
# 24                            Traded
# 25   $10,700,000              Traded
# 26                            Traded
# 27    $1,390,000              Traded
# 28    $4,500,000         Free Agency
# 29      $520,000  Amateur Free Agent
# ..           ...                 ...
# 712     $507,500       Amateur Draft
# 713     $524,525             Waivers
# 714     $590,000              Traded
# 715   $3,100,000         Free Agency
# 716                      Free Agency
# 717                           Traded
# 718     $522,500              Traded
# 719   $1,525,000              Traded
# 720                    Amateur Draft
# 721                      Free Agency
# 722     $508,500        Rule 5 Draft
# 723     $507,500              Traded
# 724     $610,000              Traded
# 725                    Amateur Draft
# 726     $530,000              Traded
# 727     $600,000         Free Agency
# 728   $6,175,000              Traded
# 729   $2,600,000             Waivers
# 730                    Amateur Draft
# 731     $510,500       Amateur Draft
# 732     $514,500              Traded
# 733     $511,900           Purchased
# 734               Amateur Free Agent
# 735                           Traded
# 736   $4,250,000         Free Agency
# 737                      Free Agency
# 738                    Amateur Draft
# 739   $5,500,000              Traded
# 740  $18,000,000         Free Agency
# 741     $511,000           Purchased
#
# [742 rows x 24 columns]

# %%
tab = soup.find("table", {"id": "players_value_pitching"})
rows = tab.find_all('tr')
# Out:
# <tr class="full_table" data-row="0"><th class="right " data-stat="ranker" scope="row">1</th><td class="left " csk="Abad,Fernando0" data-append-csv="abadfe01" data-stat="player"><a href="/players/a/abadfe01.shtml">Fernando Abad</a>*</td><td class="right " csk="30Abad,Fernando0" data-stat="age">30</td><td class="left " data-stat="team_ID">2TM</td><td class="right " data-stat="IP">46.2</td><td class="right " data-stat="G">57</td><td class="right " data-stat="GS">0</td><td class="right " data-stat="R">20</td><td class="right " data-stat="runs_avg">3.86</td><td class="right " data-stat="opp_runs_avg">4.66</td><td class="right " data-stat="runs_avg_defense">-0.17</td><td class="right " data-stat="runs_avg_sprp">-0.34</td><td class="right " data-stat="PPF_custom">101.3</td><td class="right " data-stat="runs_avg_avg_pitcher">4.55</td><td class="right " data-stat="runs_above_avg_pitch">3</td><td class="right " csk="0.34" data-stat="WAA">0.3</td><td class="right " data-stat="GR_leverage_index_avg">1.37</td><td class="right " data-stat="WAA_adj">-0.1</td><td class="right " csk="0.77" data-stat="WAR_pitch">0.8</td><td class="right " data-stat="runs_above_rep_pitch">8</td><td class="right " data-stat="waa_win_perc">.506</td><td class="right " data-stat="waa_win_perc_162">.502</td><td class="right " csk="1250000" data-stat="Salary">$1,250,000</td><td class="left " data-stat="how_acquired">Traded</td></tr>
